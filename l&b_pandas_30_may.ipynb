# %%
import pandas as pd

# %%
df=pd.DataFrame({"name":['a','b','c','d','a','b','c','d','a','b','c','d'],"s_1":[2,3,4,6,67,7,8,8,6,5,3,77],"s2":[2,4,5,7,7,8,8,8,6,5,4,2]})

# %%
df
# Out:
#    name  s_1  s2
# 0     a    2   2
# 1     b    3   4
# 2     c    4   5
# 3     d    6   7
# 4     a   67   7
# 5     b    7   8
# 6     c    8   8
# 7     d    8   8
# 8     a    6   6
# 9     b    5   5
# 10    c    3   4
# 11    d   77   2

# %%
df1=df.groupby('name')

# %%
df1

# %%
for i,j in df1:
    print(i)
    print(j)
    print(    )
# Out:
# a
#   name  s_1  s2
# 0    a    2   2
# 4    a   67   7
# 8    a    6   6
#
# b
#   name  s_1  s2
# 1    b    3   4
# 5    b    7   8
# 9    b    5   5
#
# c
#    name  s_1  s2
# 2     c    4   5
# 6     c    8   8
# 10    c    3   4
#
# d
#    name  s_1  s2
# 3     d    6   7
# 7     d    8   8
# 11    d   77   2

# %%
df1.mean()
# Out:
#             s_1        s2
# name
# a     25.000000  5.000000
# b      5.000000  5.666667
# c      5.000000  5.666667
# d     30.333333  5.666667

# %%
df=pd.read_csv("adult.csv.zmdownload")

# %%
df
# Out:
#        age          workclass  fnlwgt      education  education-num
# 0       39          State-gov   77516      Bachelors             13  \
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 21089   24            Private  233499   Some-college             10
# 21090   76          Local-gov  259612        HS-grad              9
# 21091   25            Private  236977        HS-grad              9
# 21092   39            Private  347814     Assoc-acdm             12
# 21093   36          Local-gov  197495      Bachelors             13
#
#             marital-status          occupation    relationship    race
# 0            Never-married        Adm-clerical   Not-in-family   White  \
# ...

# %%
gkk=df.groupby(['age','country'])
gkk

# %%
gkk.first()
# Out:
#                      workclass  fnlwgt      education  education-num
# age country
# 17   ?                 Private  160118           12th              8  \
#      Canada            Private  365613           10th              6
#      El-Salvador       Private  266072           10th              6
#      England           Private  270587           11th              7
#      Haiti             Private  154398           11th              7
# ...                        ...     ...            ...            ...
# 90   England           Private   88991      Bachelors             13
#      Philippines     Local-gov  187749     Assoc-acdm             12
#      Puerto-Rico       Private  171956   Some-college             10
#      South                   ?  225063   Some-college             10
#      United-States     Private   51744        HS-grad              9
#
#                          marital-status        occupation    relationship
# age country
# ...

# %%
#correlation

# %%
df.corr
# Out:
# <bound method DataFrame.corr of        age          workclass  fnlwgt      education  education-num
# 0       39          State-gov   77516      Bachelors             13  \
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 21089   24            Private  233499   Some-college             10
# 21090   76          Local-gov  259612        HS-grad              9
# 21091   25            Private  236977        HS-grad              9
# 21092   39            Private  347814     Assoc-acdm             12
# 21093   36          Local-gov  197495      Bachelors             13
#
#             marital-status          occupation    relationship    race
# ...

# %%
#how to import library
#how to load the the data

# %%
#self practice

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
# Out:
# False
