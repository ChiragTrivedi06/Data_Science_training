# %%
# bar graph

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array(["A","B","C","D"])
y= np.array([3,8,1,10])
plt.bar(x,y,color="green",width=.3)
plt.show()

# %%
plt.barh(x,y,color="red",height=0.1)
plt.show()

# %%
# pie_chart
#  ->partion  -> rating

# %%
y=np.array([35,10,40,5,10])
mylab=["a","b","c","d","e"]
col=["red","blue","green","yellow","purple"]
plt.pie(y,labels=mylab ,colors=col,startangle=0)
plt.legend(title='froot')
plt.show()# it is use in rating

# %%
y=np.array([35,10,40,5,10])
plt.pie(y,shadow=True )
plt.show()

# %%
myexplode=[.1,.5,0,0,0]

plt.pie(y,labels=mylab,explode=myexplode,colors=c,shadow=True )
plt.show()

# %%
#histo_gram
#  ->A histogram is a graph showing frequency distributions.

# %%
a=np.array([22,18,95,14,16,5,6,35,78,76,4,5,23,66,90,95])
plt.hist(a,bins=[0,10,30,40,80,100],ec="black",color="hotpink")
plt.title("histo-gram")

plt.show()

# %%
#sub graph

# %%
#plot1
x=np.array([0,1,2,3])
y=np.array([3,4,5,10])
plt.subplot(2,2,1)
plt.plot(x,y)

#plot2
x=np.array([0,1,2,3])
y=np.array([3,4,5,10])
plt.subplot(2,2,2)
plt.plot(x,y)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18564\588378467.py:13: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18564\588378467.py:19: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,2)

# %%
# scatter plot
x=np.array([2,4,6,8])
y=np.array([24,38,30,40])
plt.scatter(x,y,color=["red",'green','purple','blue'])
plt.show()
